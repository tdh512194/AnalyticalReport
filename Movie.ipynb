# %%
import pandas as pd
import numpy as np

# %%
data_movies = pd.read_csv('tmdb_5000_movies.csv')
data_credits = pd.read_csv('tmdb_5000_credits.csv')
pd.set_option('display.max_columns',None)

# %%
data_movies.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                          production_countries release_date     revenue  \
# 0  [United States of America, United Kingdom]   2009-12-10  2787965087
# 1                  [United States of America]   2007-05-19   961000000
# 2  [United Kingdom, United States of America]   2015-10-26   880674609
# 3                  [United States of America]   2012-07-16  1084939099
# 4                  [United States of America]   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
from pandas.io.json import json_normalize
import json

# %%
def json_decode(data,key):
    result = []
    data = json.loads(data) #convert to jsonjsonn from string
    for item in data #convert to list from json
        result.append(item[key])
    return result

# %%
data_movies.describe(include='all')
# Out:
#               budget                         genres  \
# count   4.803000e+03                           4803
# unique           NaN                           1175
# top              NaN  [{"id": 18, "name": "Drama"}]
# freq             NaN                            370
# mean    2.904504e+07                            NaN
# std     4.072239e+07                            NaN
# min     0.000000e+00                            NaN
# 25%     7.900000e+05                            NaN
# 50%     1.500000e+07                            NaN
# 75%     4.000000e+07                            NaN
# max     3.800000e+08                            NaN
#
#                                  homepage             id keywords  \
# count                                1712    4803.000000     4803
# unique                               1691            NaN     4222
# top     http://www.missionimpossible.com/            NaN       []
# freq                                    4            NaN      412
# mean                                  NaN   57165.484281      NaN
# std                                   NaN   88694.614033      NaN
# min                                   NaN       5.000000      NaN
# 25%                                   NaN    9014.500000      NaN
# 50%                                   NaN   14629.000000      NaN
# 75%                                   NaN   58610.500000      NaN
# max                                   NaN  459488.000000      NaN
#
#        original_language original_title  \
# count               4803           4803
# unique                37           4801
# top                   en         Batman
# freq                4505              2
# mean                 NaN            NaN
# std                  NaN            NaN
# min                  NaN            NaN
# 25%                  NaN            NaN
# 50%                  NaN            NaN
# 75%                  NaN            NaN
# max                  NaN            NaN
#
#                                                  overview   popularity  \
# count                                                4800  4803.000000
# unique                                               4800          NaN
# top     When his best friend and podcast co-host goes ...          NaN
# freq                                                    1          NaN
# mean                                                  NaN    21.492301
# std                                                   NaN    31.816650
# min                                                   NaN     0.000000
# 25%                                                   NaN     4.668070
# 50%                                                   NaN    12.921594
# 75%                                                   NaN    28.313505
# max                                                   NaN   875.581305
#
#        production_companies  \
# count                  4803
# unique                 3697
# top                      []
# freq                    351
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
#                                      production_countries release_date  \
# count                                                4803         4802
# unique                                                469         3280
# top     [{"iso_3166_1": "US", "name": "United States o...   2006-01-01
# freq                                                 2977           10
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#              revenue      runtime                          spoken_languages  \
# count   4.803000e+03  4801.000000                                      4803
# unique           NaN          NaN                                       544
# top              NaN          NaN  [{"iso_639_1": "en", "name": "English"}]
# freq             NaN          NaN                                      3171
# mean    8.226064e+07   106.875859                                       NaN
# std     1.628571e+08    22.611935                                       NaN
# min     0.000000e+00     0.000000                                       NaN
# 25%     0.000000e+00    94.000000                                       NaN
# 50%     1.917000e+07   103.000000                                       NaN
# 75%     9.291719e+07   118.000000                                       NaN
# max     2.787965e+09   338.000000                                       NaN
#
#           status                 tagline   title  vote_average    vote_count
# count       4803                    3959    4803   4803.000000   4803.000000
# unique         3                    3944    4800           NaN           NaN
# top     Released  Based on a true story.  Batman           NaN           NaN
# freq        4795                       3       2           NaN           NaN
# mean         NaN                     NaN     NaN      6.092172    690.217989
# std          NaN                     NaN     NaN      1.194612   1234.585891
# min          NaN                     NaN     NaN      0.000000      0.000000
# 25%          NaN                     NaN     NaN      5.600000     54.000000
# 50%          NaN                     NaN     NaN      6.200000    235.000000
# 75%          NaN                     NaN     NaN      6.800000    737.000000
# max          NaN                     NaN     NaN     10.000000  13752.000000

# %%
data_credits.describe(include='all')
# Out:
#              movie_id   title  cast  crew
# count     4803.000000    4803  4803  4803
# unique            NaN    4800  4761  4776
# top               NaN  Batman    []    []
# freq              NaN       2    43    28
# mean     57165.484281     NaN   NaN   NaN
# std      88694.614033     NaN   NaN   NaN
# min          5.000000     NaN   NaN   NaN
# 25%       9014.500000     NaN   NaN   NaN
# 50%      14629.000000     NaN   NaN   NaN
# 75%      58610.500000     NaN   NaN   NaN
# max     459488.000000     NaN   NaN   NaN

# %% [markdown]
# ## Clean missing values ##

# %%
def nan_clean(data,replace=False,alter=''):
    nan_count = len(data) - data.count()
    if np.logical_and(replace,nan_count > 0):
        data.fillna(alter,inplace=True)
        print('Replaced NaN with {}'.format(alter))
        print('Number of cleaned NANs:{}'.format(nan_count))
    else:
        print('Number of NANs:{}'.format(nan_count))
    return

# %%
nan_clean(data_movies.homepage,replace=True)
# Out:
# Number of NANs:0

# %%
nan_clean(data_movies.release_date,replace=True)
# Out:
# Replaced NaN with
# Number of cleaned NANs:1

# %%
nan_clean(data_movies.overview,replace=True)
# Out:
# Replaced NaN with
# Number of cleaned NANs:3

# %%
nan_clean(data_movies.runtime,replace=True,alter=0)
# Out:
# Replaced NaN with 0
# Number of cleaned NANs:2

# %%
nan_clean(data_movies.tagline,replace=True)
# Out:
# Replaced NaN with
# Number of cleaned NANs:844

# %% [markdown]
# ## <span style="color:red"> **Questions** </span>  ##

# %% [markdown]
# ### 1.What areas have the most influence on revenue? ###

# %% [markdown]
# + Feature engineering: convert the nested jsons in **production_countries** column to list of countries

# %%
data_movies.production_countries = data_movies.production_countries.apply(json_decode,key='name')

# %%
data_movies.production_countries.head()
# Out:
# 0    [United States of America, United Kingdom]
# 1                    [United States of America]
# 2    [United Kingdom, United States of America]
# 3                    [United States of America]
# 4                    [United States of America]
# Name: production_countries, dtype: object

# %% [markdown]
# + query the top 100 movies with highest **revenue** and their respective **production_countries**

# %%
movie_top = data_movies.nlargest(100,'revenue')[['title','revenue','production_countries']]

# %%
movie_top
# Out:
#                                                   title     revenue  \
# 0                                                Avatar  2787965087
# 25                                              Titanic  1845034188
# 16                                         The Avengers  1519557910
# 28                                       Jurassic World  1513528810
# 44                                            Furious 7  1506249360
# 7                               Avengers: Age of Ultron  1405403694
# 124                                              Frozen  1274219009
# 31                                           Iron Man 3  1215439994
# 546                                             Minions  1156730962
# 26                           Captain America: Civil War  1153304495
# 52                       Transformers: Dark of the Moon  1123746996
# 329       The Lord of the Rings: The Return of the King  1118888979
# 29                                              Skyfall  1108561013
# 36                      Transformers: Age of Extinction  1091405097
# 3                                 The Dark Knight Rises  1084939099
# 153   [Czech Republic, United States of America, Uni...
# 426                          [United States of America]
# 134                   [China, United States of America]
# 809                          [United States of America]
# 95    [Canada, United States of America, United King...
# 1145                         [United States of America]
# 137                          [United States of America]
# 14           [United Kingdom, United States of America]
# 514                          [United States of America]
# 199                          [United States of America]
# 102                 [Germany, United States of America]
# 88                           [United States of America]
# 230                          [United States of America]
# 126                          [United States of America]
# 181                          [United States of America]
# 339                          [United States of America]
# 270                          [United States of America]
# 204                          [United States of America]
# 115                          [United States of America]
# 18                           [United States of America]
#
# [100 rows x 3 columns]

# %%
countries_set = set()
for data in movie_top.production_countries:
    for item in data:
        countries_set.add(item)
print(countries_set)
# Out:
# {'Bahamas', 'Germany', 'Czech Republic', 'Japan', 'Dominica', 'United States of America', 'Canada', 'Australia', 'Malta', 'New Zealand', 'Jamaica', 'United Arab Emirates', 'China', 'United Kingdom', 'France'}

# %% [markdown]
# count the occurence of each country in the sorted list

# %%
from collections import defaultdict
country_top = defaultdict(int)
for data in movie_top.production_countries:
    for item in data:
        country_top[item] += 1
print(country_top)
# Out:
# defaultdict(<class 'int'>, {'United States of America': 100, 'United Kingdom': 19, 'Japan': 1, 'China': 2, 'New Zealand': 6, 'Jamaica': 1, 'Bahamas': 1, 'Dominica': 1, 'Germany': 2, 'Canada': 2, 'Malta': 1, 'France': 1, 'Australia': 1, 'Czech Republic': 1, 'United Arab Emirates': 1})

# %% [markdown]
# it can be seen that the *USA* plays the dominance role as it produces all of the top 100 movies from the list, following is *UK* with 19 movies and *New Zealand* with 6 movies

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.Series(dict(country_top),name='count')
df.index.name='country'
df.plot(kind='barh',grid=True)

# %% [markdown]
# to assess the quatitative value, I now calculate the average revenue produced by each country from the top 100 list

# %%
country_avg_rvn = defaultdict(int)
for index, row in movie_top.iterrows():
    for item in row['production_countries']:
       country_avg_rvn[item] += row['revenue']
for key in country_avg_rvn:
    country_avg_rvn[key] = country_avg_rvn[key]/country_top[key]
print(country_avg_rvn)
# Out:
# defaultdict(<class 'int'>, {'United States of America': 889420954.07, 'United Kingdom': 951425322.8421053, 'Japan': 1506249360.0, 'China': 948885066.5, 'New Zealand': 975344683.1666666, 'Jamaica': 1065659812.0, 'Bahamas': 1065659812.0, 'Dominica': 1065659812.0, 'Germany': 765058371.5, 'Canada': 722386806.0, 'Malta': 767820459.0, 'France': 767820459.0, 'Australia': 738599701.0, 'Czech Republic': 694713380.0, 'United Arab Emirates': 694713380.0})

# %%
df = pd.Series(dict(country_avg_rvn),name='avg_rvn')
df.index.name='country'
df.plot(kind='barh',grid=True)

# %% [markdown]
# Although taking part in producing all of the top 100 movies with highest revenues, the *USA* doesn't has their average revenue per movie at the top of the list. *Japan* only contributes to 1 movie from the top 100 list but it has very high revenue, making *Japan* top the list.

# %% [markdown]
# At this point, we still need further exploration to test the relevancy of *USA*. We now see to what extent  the *USA* contributes to the whole list's revenue by counting its occurence from the whole list:

# %%
count = 0
for item in data_movies.production_countries:
    if 'United States of America' in item:
        count +=1
print("The USA produces {0:.0f}% of the movies".format((count/len(data_movies.production_countries))*100))
# Out:
# The USA produces 82% of the movies
